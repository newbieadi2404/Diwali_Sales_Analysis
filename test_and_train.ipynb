# %%
# import python libraries

import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt # visualizing data
import warnings
import seaborn as sns

# %%
warnings.filterwarnings('ignore')

# %%
# import csv file
data = pd.read_csv('Diwali Sales Data.csv', encoding= 'unicode_escape')

# %%
data.sample(5)
# Out:
#       User_ID     Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 1207  1005630  Divyeshkumar  P00216142      F     36-45   44               0
# 9714  1002845       Theresa  P00184242      F     26-35   30               0
# 3838  1002911         Jesal  P00058042      M     26-35   26               0
# 1460  1003620        Catini  P00248342      F     26-35   27               1
# 825   1003378        Chikku  P00053942      F     18-25   23               1
#
#                State      Zone  Occupation  Product_Category  Orders   Amount  \
# 1207           Delhi   Central  Healthcare  Footwear & Shoes       1  16649.0
# 9714          Kerala  Southern  Healthcare   Household items       3   3790.0
# 3838  Madhya Pradesh   Central        Govt   Sports Products       3  11048.0
# 1460           Delhi   Central   IT Sector  Footwear & Shoes       2  16294.0
# 825            Bihar   Eastern        Govt              Food       1  19143.0
#
#       Status  unnamed1
# ...

# %%
data.shape
# Out:
# (11251, 15)

# %%
data.head(10)
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
# 5  1000588       Joni  P00057942      M     26-35   28               1
# 6  1001132       Balk  P00018042      F     18-25   25               1
# 7  1002092   Shivangi  P00273442      F       55+   61               0
# 8  1003224     Kushal  P00205642      M     26-35   35               0
# 9  1003650      Ginny  P00031142      F     26-35   26               1
#
#               State      Zone       Occupation Product_Category  Orders  \
# 0       Maharashtra   Western       Healthcare             Auto       1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
#drop unrelated/blank columns
data.drop(['Status', 'unnamed1'], axis=1, inplace=True)

# %%
#check for true or false values (false means there's something =1 )
pd.isnull(data)
# Out:
#        User_ID  Cust_name  Product_ID  Gender  Age Group    Age  \
# 0        False      False       False   False      False  False
# 1        False      False       False   False      False  False
# 2        False      False       False   False      False  False
# 3        False      False       False   False      False  False
# 4        False      False       False   False      False  False
# ...        ...        ...         ...     ...        ...    ...
# 11246    False      False       False   False      False  False
# 11247    False      False       False   False      False  False
# 11248    False      False       False   False      False  False
# 11249    False      False       False   False      False  False
# 11250    False      False       False   False      False  False
#
#        Marital_Status  State   Zone  Occupation  Product_Category  Orders  \
# 0               False  False  False       False             False   False
# ...

# %%
#check for null values
pd.isnull(data).sum()
# Out:
# User_ID              0
# Cust_name            0
# Product_ID           0
# Gender               0
# Age Group            0
# Age                  0
# Marital_Status       0
# State                0
# Zone                 0
# Occupation           0
# Product_Category     0
# Orders               0
# Amount              12
# dtype: int64

# %%
data.shape
# Out:
# (11251, 13)

# %%
# drop null values
data.dropna(inplace=True)

# %%
pd.isnull(data).sum()
# Out:
# User_ID             0
# Cust_name           0
# Product_ID          0
# Gender              0
# Age Group           0
# Age                 0
# Marital_Status      0
# State               0
# Zone                0
# Occupation          0
# Product_Category    0
# Orders              0
# Amount              0
# dtype: int64

# %%
# change data type
data['Amount'] = data['Amount'].astype('int')

# %%
data['Amount'].dtypes
# Out:
# dtype('int32')

# %%
data.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
#rename column
data.rename(columns= {'Marital_Status':'Shaadi'})
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Shaadi  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28       0
# 1      1000732       Kartik  P00110942      F     26-35   35       1
# 2      1001990        Bindu  P00118542      F     26-35   35       1
# 3      1001425       Sudevi  P00237842      M      0-17   16       0
# 4      1000588         Joni  P00057942      M     26-35   28       1
# ...        ...          ...        ...    ...       ...  ...     ...
# 11246  1000695      Manning  P00296942      M     18-25   19       1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33       0
# 11248  1001209        Oshin  P00201342      F     36-45   40       0
# 11249  1004023       Noonan  P00059442      M     36-45   37       0
# 11250  1002744      Brumley  P00281742      F     18-25   19       0
#
#                 State      Zone       Occupation Product_Category  Orders  \
# ...

# %%
# describe() method returns description of the data in the DataFrame (i.e. count, mean, std, etc)
data.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount
# count  1.123900e+04  11239.000000    11239.000000  11239.000000  11239.000000
# mean   1.003004e+06     35.410357        0.420055      2.489634   9453.610553
# std    1.716039e+03     12.753866        0.493589      1.114967   5222.355168
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      2.000000   5443.000000
# 50%    1.003064e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004426e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000

# %%
# use describe() for specific columns
data[['Age', 'Orders', 'Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11239.000000  11239.000000  11239.000000
# mean      35.410357      2.489634   9453.610553
# std       12.753866      1.114967   5222.355168
# min       12.000000      1.000000    188.000000
# 25%       27.000000      2.000000   5443.000000
# 50%       33.000000      2.000000   8109.000000
# 75%       43.000000      3.000000  12675.000000
# max       92.000000      4.000000  23952.000000

# %%
data['Age'].mean()
# Out:
# 35.41035679330901

# %%
mean_weight = data['Age'].mean()
median_weight = data['Age'].median()

# %%
print(mean_weight,median_weight)
# Out:
# 35.41035679330901 33.0

# %%
from sklearn.preprocessing import OrdinalEncoder

data_encoded = data.copy()

cat_cols = data.select_dtypes(include=['object']).columns
for col in cat_cols:
    oe = OrdinalEncoder()
    data_encoded[col]=oe.fit_transform(data_encoded[[col]])
    print(oe.categories_)
# Out:
# [array(['Aaron', 'Aarushi', 'Aastha', ..., 'Zypern', 'liebe', 'percer'],
#       dtype=object)]
# [array(['P00000142', 'P00000242', 'P00000342', ..., 'P0099342', 'P0099442',
#        'P0099742'], dtype=object)]
# [array(['F', 'M'], dtype=object)]
# [array(['0-17', '18-25', '26-35', '36-45', '46-50', '51-55', '55+'],
#       dtype=object)]
# [array(['Andhra\xa0Pradesh', 'Bihar', 'Delhi', 'Gujarat', 'Haryana',
#        'Himachal Pradesh', 'Jharkhand', 'Karnataka', 'Kerala',
#        'Madhya Pradesh', 'Maharashtra', 'Punjab', 'Rajasthan',
#        'Telangana', 'Uttar Pradesh', 'Uttarakhand'], dtype=object)]
# [array(['Central', 'Eastern', 'Northern', 'Southern', 'Western'],
#       dtype=object)]
# [array(['Agriculture', 'Automobile', 'Aviation', 'Banking', 'Chemical',
#        'Construction', 'Food Processing', 'Govt', 'Healthcare',
#        'Hospitality', 'IT Sector', 'Lawyer', 'Media', 'Retail', 'Textile'],
#       dtype=object)]
# ...

# %%
data_encoded.head(20)
# Out:
#     User_ID  Cust_name  Product_ID  Gender  Age Group  Age  Marital_Status  \
# 0   1002903      991.0       774.0     0.0        2.0   28               0
# 1   1000732      596.0       644.0     0.0        2.0   35               1
# 2   1001990      150.0       714.0     0.0        2.0   35               1
# 3   1001425     1102.0      1507.0     1.0        0.0   16               0
# 4   1000588      574.0       387.0     1.0        2.0   28               1
# 5   1000588      574.0       387.0     1.0        2.0   28               1
# 6   1001132      106.0       123.0     0.0        1.0   25               1
# 8   1003224      639.0      1282.0     1.0        2.0   35               0
# 9   1003650      433.0       214.0     0.0        2.0   26               1
# 10  1003829      483.0      1261.0     1.0        2.0   34               0
# 11  1000214      593.0       719.0     0.0        1.0   20               0
# ...

# %%
X = data_encoded.drop('Occupation', axis=1) 
Y = data_encoded['Occupation']

# %%
Y
# Out:
# 0         8.0
# 1         7.0
# 2         1.0
# 3         5.0
# 4         6.0
#          ...
# 11246     4.0
# 11247     8.0
# 11248    14.0
# 11249     0.0
# 11250     8.0
# Name: Occupation, Length: 11239, dtype: float64

# %%
from sklearn.ensemble import RandomForestRegressor

from sklearn.model_selection import cross_val_score

rf = RandomForestRegressor(n_estimators=100,random_state=42)
scores = cross_val_score(rf,X,Y,cv=5,scoring='r2')
print(scores.mean())
# Out:
# -0.0267122954974802

# %%
pip install xgboost
# Out:
# ...
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.1/124.9 MB 1.5 MB/s eta 0:01:22
#    ---------------------------------------- 0.3/124.9 MB 2.8 MB/s eta 0:00:45
#    ---------------------------------------- 0.4/124.9 MB 2.9 MB/s eta 0:00:43
#    ---------------------------------------- 0.6/124.9 MB 2.8 MB/s eta 0:00:45
#    ---------------------------------------- 0.7/124.9 MB 2.9 MB/s eta 0:00:43
#    ---------------------------------------- 0.9/124.9 MB 2.9 MB/s eta 0:00:43
#    ---------------------------------------- 1.0/124.9 MB 3.1 MB/s eta 0:00:41
#    ---------------------------------------- 1.1/124.9 MB 2.7 MB/s eta 0:00:46
#    ---------------------------------------- 1.3/124.9 MB 3.0 MB/s eta 0:00:42
#    ---------------------------------------- 1.5/124.9 MB 3.1 MB/s eta 0:00:41
# ...

# %%
from xgboost import XGBRegressor

# %%
from xgboost import XGBRegressor
xg = XGBRegressor(n_estimators=100,random_state=42)
scores = cross_val_score(xg,X,Y,cv=5,scoring='r2')
print(scores.mean())
# Out:
# -0.21401300304635668

# %%
xg = XGBRegressor(n_estimators=100,random_state=42)

xg1 = xg.fit(X,Y)
pd.DataFrame({
    'feature':X.columns,
    'XGB_importance':xg1.feature_importances_

}).sort_values(by='XGB_importance',ascending=False)
# Out:
#              feature  XGB_importance
# 11            Amount        0.092720
# 5                Age        0.091072
# 7              State        0.086280
# 1          Cust_name        0.086131
# 2         Product_ID        0.085667
# 6     Marital_Status        0.085248
# 8               Zone        0.084693
# 9   Product_Category        0.081576
# 0            User_ID        0.080647
# 10            Orders        0.076578
# 3             Gender        0.074776
# 4          Age Group        0.074612

# %%
['Amount','Age','State','Cust_name','Product_ID']
# Out:
# ['Amount', 'Age', 'State', 'Cust_name', 'Product_ID']

# %%
from xgboost import XGBRegressor
xg = XGBRegressor(n_estimators=100,random_state=42)
scores = cross_val_score(xg1,X.drop(['Amount','Age','State','Cust_name','Product_ID'],axis=1),Y,cv=5,scoring='r2')
print(scores.mean())
# Out:
# -0.14750940008340488

# %%
final_data = X.drop(columns=['Amount','Age','State','Cust_name','Product_ID'],axis=1)

# %%
final_data
# Out:
#        User_ID  Gender  Age Group  Marital_Status  Zone  Product_Category  \
# 0      1002903     0.0        2.0               0   4.0               0.0
# 1      1000732     0.0        2.0               1   3.0               0.0
# 2      1001990     0.0        2.0               1   0.0               0.0
# 3      1001425     1.0        0.0               0   3.0               0.0
# 4      1000588     1.0        2.0               1   4.0               0.0
# ...        ...     ...        ...             ...   ...               ...
# 11246  1000695     1.0        1.0               1   4.0              12.0
# 11247  1004089     1.0        2.0               0   2.0              17.0
# 11248  1001209     0.0        3.0               0   0.0              12.0
# 11249  1004023     1.0        3.0               0   3.0              12.0
# 11250  1002744     0.0        1.0               0   4.0              12.0
#
#        Orders
# 0           1
# 1           3
# 2           3
# 3           2
# ...

# %%
from xgboost import XGBRegressor

# %%
xg_final = XGBRegressor()

# %%
xg_final.fit(final_data,Y)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

# %%
X_train,X_test,Y_train,Y_test = train_test_split(final_data,Y,
                                                 test_size=0.20,
                                                 random_state=42)

# %%
xg_final.fit(X_train,Y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %%
Y_pred = xg_final.predict(X_test)

# %%
mean_absolute_error(Y_test,Y_pred)
# Out:
# 3.4515774313532797

# %%
# Prediction on unseen data
input_data = np.array([[141.6180, 9.0, 1.0, 1.0, 24, 8.0, 6.24]])
pred = xg_final.predict(input_data)
print(pred)
# Out:
# [6.512916]

# %%
import joblib

# %%
joblib.dump(xg_final,'diwali_sales_model')
# Out:
# ['diwali_sales_model']

# %%
model = joblib.load('diwali_sales_model')

# %%
pred = model.predict(np.array([[141.6180,9.0,1.0,1.0,24,8.0,6.24]]))[0]
print(pred)
# Out:
# 6.512916

# %%
import tkinter as tk
from tkinter import ttk
from IPython.display import display

# Create a Tkinter window
window = tk.Tk()
window.title("Diwali Sales Data GUI")

# Create labels and entries for each field
user_id_label = tk.Label(window, text="User ID:")
user_id_label.grid(row=0, column=0, padx=5, pady=5)
user_id_entry = tk.Entry(window)
user_id_entry.grid(row=0, column=1, padx=5, pady=5)

cust_name_label = tk.Label(window, text="Customer Name:")
cust_name_label.grid(row=1, column=0, padx=5, pady=5)
cust_name_entry = tk.Entry(window)
cust_name_entry.grid(row=1, column=1, padx=5, pady=5)

product_id_label = tk.Label(window, text="Product ID:")
product_id_label.grid(row=2, column=0, padx=5, pady=5)
product_id_entry = tk.Entry(window)
product_id_entry.grid(row=2, column=1, padx=5, pady=5)

gender_label = tk.Label(window, text="Gender:")
gender_label.grid(row=3, column=0, padx=5, pady=5)
gender_var = tk.StringVar()
gender_var.set("Male")  # default value
gender_option = tk.OptionMenu(window, gender_var, "Male", "Female")
gender_option.grid(row=3, column=1, padx=5, pady=5)

age_group_label = tk.Label(window, text="Age Group:")
age_group_label.grid(row=4, column=0, padx=5, pady=5)
age_group_var = tk.StringVar()
age_group_var.set("18-24")  # default value
age_group_option = tk.OptionMenu(window, age_group_var, "18-24", "25-34", "35-44", "45-54", "55-64", "65+")
age_group_option.grid(row=4, column=1, padx=5, pady=5)

age_label = tk.Label(window, text="Age:")
age_label.grid(row=5, column=0, padx=5, pady=5)
age_entry = tk.Entry(window)
age_entry.grid(row=5, column=1, padx=5, pady=5)

marital_status_label = tk.Label(window, text="Marital Status:")
marital_status_label.grid(row=6, column=0, padx=5, pady=5)
marital_status_var = tk.StringVar()
marital_status_var.set("Single")  # default value
marital_status_option = tk.OptionMenu(window, marital_status_var, "Single", "Married", "Divorced", "Widowed")
marital_status_option.grid(row=6, column=1, padx=5, pady=5)

state_label = tk.Label(window, text="State:")
state_label.grid(row=7, column=0, padx=5, pady=5)
state_entry = tk.Entry(window)
state_entry.grid(row=7, column=1, padx=5, pady=5)

zone_label = tk.Label(window, text="Zone:")
zone_label.grid(row=8, column=0, padx=5, pady=5)
zone_entry = tk.Entry(window)
zone_entry.grid(row=8, column=1, padx=5, pady=5)

occupation_label = tk.Label(window, text="Occupation:")
occupation_label.grid(row=9, column=0, padx=5, pady=5)
occupation_entry = tk.Entry(window)
occupation_entry.grid(row=9, column=1, padx=5, pady=5)

product_category_label = tk.Label(window, text="Product Category:")
product_category_label.grid(row=10, column=0, padx=5, pady=5)
product_category_entry = tk.Entry(window)
product_category_entry.grid(row=10, column=1, padx=5, pady=5)

orders_label = tk.Label(window, text="Orders:")
orders_label.grid(row=11, column=0, padx=5, pady=5)
orders_entry = tk.Entry(window)
orders_entry.grid(row=11, column=1, padx=5, pady=5)

amount_label = tk.Label(window, text="Amount:")
amount_label.grid(row=12, column=0, padx=5, pady=5)
amount_entry = tk.Entry(window)
amount_entry.grid(row=12, column=1, padx=5, pady=5)

# Create a submit button
def submit_data():
    user_id = user_id_entry.get()
    cust_name = cust_name_entry.get()
    product_id = product_id_entry.get()
    gender = gender_var.get()
    age_group = age_group_var.get()
    age = age_entry.get()
    marital_status = marital_status_var.get()
    state = state_entry.get()
    zone = zone_entry.get()
    occupation = occupation_entry.get()
    product_category = product_category_entry.get()
    orders = orders_entry.get()
    amount = amount_entry.get()
    
    # Print the data to the console
    print("User ID:", user_id)
    print("Customer Name:", cust_name)
    print("Product ID:", product_id)
    print("Gender:", gender)
    print("Age Group:", age_group)
    print("Age:", age)
    print("Marital Status:", marital_status)
    print("State:", state)
    print("Zone:", zone)
    print("Occupation:", occupation)
    print("Product Category:", product_category)
    print("Orders:", orders)
    print("Amount:", amount)

submit_button = tk.Button(window, text="Submit", command=submit_data)
submit_button.grid(row=13, column=0, columnspan=2, padx=5, pady=5)

# Start the Tkinter event loop
window.mainloop()
# Out:
# User ID: 1002903
# Customer Name: Sanskriti
# Product ID: P00125942
# Gender: Female
# Age Group: 25-34
# Age: 28
# Marital Status: Single
# State: Maharashtra
# Zone: Western
# Occupation: Healthcare
# Product Category: Auto
# Orders: 1
# Amount: 23952
